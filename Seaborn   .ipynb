# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
housing=pd.read_csv(r'C:/data/house_sales.csv')
sns.set(style="white",color_codes=True)
sns.boxplot(x='bedrooms',y='price',data=housing)

# %%
# How to remove the axis lines
import pandas as pd
import numpy as np
import seaborn as sns
housing=pd.read_csv(r'C:/data/house_sales.csv')
sns.set(style="white",color_codes=True)
sns.boxplot(x='bedrooms',y='price',data=housing)
sns.despine(offset=10, trim=True) # How to remove the axis lines

# %%
housing=sns.color_palette() # To check the available color palettes
sns.palplot(housing)
