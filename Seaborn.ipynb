# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn library is used for data visualization based on matplotlib.
#
# Seaborn allows the creation of statistical graphics.

# %% [markdown]
# ### Functionalities

# %% [markdown]
# Allows companies between multiple variable
#
# Supports multi-plot grids
#
# Available univariate and bivariate visualizations
#
# Availability of different color palettes.
#
# Estimates and plots linear regression automatically

# %% [markdown]
# ### Seaborn vs matplotlib

# %% [markdown]
# Seaborn fixes two shortcomings of matplotlib:
#
#     Matplotlib settings are difficult to figure out. Seaborn comes with numerous customized themes and high-level interfaces.
#     Matplotlib doesn't serve well when it comes to dealing with DataFrames, while seaborn functions actually work on DataFrames

# %% [markdown]
# To install seaborn:
#
# pip install seaborn
#
# conda install seaborn (from anaconda promt)

# %% [markdown]
# Seaborn dependancies: numpy, scipy, matplotlib, pandas, statsmodel (for statistics in python)

# %% [markdown]
# ### Python seaborn functions

# %% [markdown]
# Visualizing Statistical Relationships.
#     Processing of understanding relationships between variables of a dataset.
#
# Ploting with Categorical Data.
#     Main variable id further divided into discrete groups.
#
# Visualizing the distribution of a dataset.
#     Understanding dataset with content to being univariate or bivariate

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = sns.load_dataset("flights") #Loading data sets from github using seaborn

# %%
house = pd.read_csv(r'/root/data/housing.csv')

# %%
sns.relplot(x='population', y='total_bedrooms', data=house) #Plotting in two dimension

# %%
 sns.relplot(x='population', y='total_bedrooms', hue='households', data=house) #Plotting in three dimension

# %%
insurance = pd.read_csv(r'C:/data/datafile (1).csv')

# %%
sns.relplot(x='population', y='total_bedrooms',data=house,kind="line") #ploting a line graph

# %% [markdown]
# ### Ploting a categorical dataset

# %%
plant=pd.read_csv(r'/root/data/PlantGrowth.csv')

# %%
sns.catplot(x='group',y='weight',data=plant) # Scatter plot

# %%
sns.catplot(x='group',y='weight',kind='violin',data=plant) # voilin plot

# %%
sns.catplot(x='group',y='weight',kind='boxen',data=plant)

# %% [markdown]
# ### Visualizing the distribution of a dataset

# %% [markdown]
# It involves understanding datasets with context to being univariate or bivariate

# %%
from scipy import stats

# %%
c=np.random.normal(loc=5, size=100, scale=2) # For univariate

# %%
sns.distplot(c)

# %%
x=pd.DataFrame({'Day':[1,2,3,4,5,6,7],'Grocery':[30,80,45,23,51,46,76],'Clothes':[13,40,34,23,54,67,98],'utensils':[32,65,32,12,87,45,26]})
y=pd.DataFrame({'Day':[8,9,10,11,12,13,14],'Grocery':[56,89,45,12,23,56,45],'Clothes':[13,46,65,79,84,51,19],'utensils':[12,56,45,78,56,13,46]})
mean, cov = [0, 1], [(1, -5), (-5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
with sns.axes_style("white"):
    sns.jointplot(x=x, y=y, kind="kde", color="b")
# Out:
# /root/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: covariance is not positive-semidefinite.
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Multi-plot grids

# %% [markdown]
# Graphs are plotted side-by-side using the same scale and axes to aid comparison.

# %%
from sklearn import datasets
import seaborn as sns
import pandas as pd
data = pd.read_datasets("iris")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d26fcca17c74> in <module>
#       2 import seaborn as sns
#       3 import pandas as pd
# ----> 4 data = pd.read_datasets("iris")
#
# AttributeError: module 'pandas' has no attribute 'read_datasets'

# %%
b=sns.FacetGrid(plant, col="group")
b.map(plt.hist, "weight")

# %%
c=sns.PairGrid(house)
c.map(plt.scatter)

# %% [markdown]
# ### Plot-Aesthetics

# %% [markdown]
# Deals with making our plots more attractive and delightful: using various themes and color-pallettes

# %%
sns.set(style="darkgrid") # Changing the background to dark
c=sns.PairGrid(house)
c.map(plt.scatter)

# %%
sns.set(style="dark") #changing the backgroud
c=sns.PairGrid(house)
c.map(plt.scatter)

# %%
# How to remove the axis lines
housing=pd.read_csv(r'C:/data/house_sales.csv')
sns.set(style="white",color_codes=True)
sns.boxplot(x='bedrooms',y='price',data=housing)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
housing=pd.read_csv(r'C:/data/house_sales.csv')
sns.set(style="white",color_codes=True)
sns.boxplot(x='bedrooms',y='price',data=housing)

# %%
housing=sns.color_palette() # To check the available color palettes
sns.palplot(housing)

# %%
plt.style.use('seaborn')

# %%
sns.get_dataset_names()
# Out:
# /root/anaconda3/lib/python3.7/site-packages/seaborn/utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file /root/anaconda3/lib/python3.7/site-packages/seaborn/utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
ax = sns.scatterplot('total_bedrooms',)

# %%
sns.heatmap(house.corr(), annot=True)

# %%
house.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
sns.scatterplot('population', 'households',data=house)

# %%
sns.scatterplot(house.population, house.households, hue=house.total_bedrooms)

# %%
house.plot.scatter('population', 'total_bedrooms')

# %%
sns.relplot('population','total_bedrooms',data=house, hue='households')

# %%
sns.relplot('population','total_bedrooms',data=house, hue='households', kind='scatter')

# %%
plt.style.use('ggplot')

# %%
sns.relplot('population','total_bedrooms',data=house, hue='households')

# %%
sns.relplot('population','total_bedrooms',data=house, hue='households', size='latitude')

# %%
sns.relplot('population','total_bedrooms',data=house, hue='households', style='ocean_proximity')

# %%
house.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
house.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
sns.relplot('population','housing_median_age', data=house, hue='median_income', size='median_house_value', style='ocean_proximity', row='total_rooms', col='total_bedrooms')

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot('tip','total_bill',data=tips, hue='time',size='size',style='day',row='smoker',col='sex')

# %% [markdown]
# ## Categorical plots

# %%
sns.relplot('day','total_bill',data=tips, hue='smoker',size='time',style='sex')

# %%
sns.scatterplot('day','total_bill',data=tips,hue='time',size='smoker')

# %%
sns.catplot('day','total_bill',data=tips,hue='time', kind='strip')

# %%
sns.catplot('day','total_bill',data=tips,hue='time', kind='boxen')

# %%
sns.catplot('day','total_bill',data=tips,hue='time', kind='violin')

# %%
sns.catplot('sex','total_bill',hue='day',kind='strip',data=tips)

# %%
sns.catplot('sex','total_bill',data=tips, hue='day', kind='strip',jitter=True,dodge=True)

# %%
sns.catplot('sex','total_bill',data=tips, hue='day', kind='strip',jitter=False,dodge=True)

# %%
sns.catplot('sex','total_bill',hue='day',kind='box',data=tips)

# %%
sns.catplot('sex','total_bill',data=tips, hue='day', kind='violin',jitter=False,dodge=True)

# %%
sns.catplot('sex','total_bill',data=tips, hue='day', kind='strip',jitter=False,dodge=True)

# %%
sns.boxplot('sex','total_bill',data=tips, hue='day', color='.8')

# %%
sns.boxplot('sex','total_bill',data=tips, hue='day', color='r')

# %%
sns.boxplot('sex','total_bill',data=tips, hue='day', color='.8', showfliers=True)

# %%
sns.boxplot('sex','total_bill',data=tips, hue='day', color='.8', showfliers=False)

# %%
sns.boxplot('sex','total_bill',data=tips, hue='day', color='.8',dodge=True, showfliers=True)
sns.swarmplot('sex','total_bill',data=tips, hue='day')

# %%
sns.boxplot('sex','total_bill',data=tips, color='.8',dodge=True, showfliers=True)
sns.swarmplot('sex','total_bill',data=tips, hue='day')
plt.gcf().set_size_inches(11,8)

# %%
sns.relplot(x="total_bill", y="tip", data=tips, kind="scatter",
            hue="sex", 
            col='smoker', row='day',
            row_order=["Thur", "Fri", "Sat", 'Sun']
            )

# %%
fg = sns.FacetGrid(tips, col='smoker', row='day',hue='sex', row_order=['Thur','Fri','Sat','Sun'])
fg.map(plt.scatter, "total_bill","tip")

# %%
fg.axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe373a603d0>,
# ...
#       dtype=object)

# %%
fg = sns.FacetGrid(tips, col='smoker', row='day',hue='sex', row_order=['Thur','Fri','Sat','Sun'])
fg.map(plt.scatter, "total_bill","tip")
fg.axes[1][1].plot([10,13,23],[3,4,2])

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.pairplot(tips)

# %%
ax = sns.pairplot(tips, hue='day')

# %%
ax.axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe3726f7490>,
# ...
#       dtype=object)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
jp = sns.jointplot('total_bill','tip', data=tips)

# %%
jp = sns.jointplot('total_bill','tip',data=tips, kind='hex')

# %%
jp = sns.jointplot('total_bill','tip', data=tips, kind='kde')
